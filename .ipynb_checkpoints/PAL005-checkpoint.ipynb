# %% [markdown]
# ## Context

# %% [markdown]
# - the big picture question is what happens when you have multiple cytokines like IFNg, IL-4, IL-6
# - We can see from other experiments that IFNg tends to dominate, but is it because other signals are insufficient or that IFNg overrides them ?
#     - we know from textbooks that the cytokines of one module, including IFNg, tend to inhibit the differentiation of other clusters
# - to test that, we've knocked out IFNgR with a CRISPR screen
# - what we would like to do is a sort of 'subcluster' analysis where we subset the data on the knockout status and see if there are changes in the cell populations
#     - for instance, we would be curious to see the Th1 population disappear and other populations to appear
#     - while this may show up in the clustering, the populations are similar enough that that might not happen
#     - so, we can settle on differential expression

# %% [markdown]
# - eric explained that in this case doublet detection is really important
# - we can use CITE data to remove the doublets since each cell should only have one particular flavor of a pancell antibody stain
#     - so, if any cell has two that should mean that we drop it

# %% [markdown]
# ## Libraries + Settings

# %%
import scanpy as sc
import pertpy as pt
import pandas as pd
import muon as mu
import pertpy as pt
from matplotlib import pyplot as plt
import plotnine as p9

# %%
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Data Import

# %%
mdata = mu.read_h5mu("/lustre/fs4/cao_lab/scratch/plaffont/personal_datasets/CTR02/ctr02.h5mu")
mdata
# Out:
# MuData object with n_obs × n_vars = 42903 × 32303
#   var:	'gene_ids', 'feature_types', 'genome', 'pattern', 'read', 'sequence', 'target_gene_id', 'target_gene_name'
#   3 modalities
#     rna:	42903 x 32286
#       var:	'gene_ids', 'feature_types', 'genome'
#     guide:	42903 x 12
#       var:	'gene_ids', 'feature_types', 'pattern', 'read', 'sequence', 'target_gene_id', 'target_gene_name'
#     cite:	42903 x 5
#       var:	'gene_ids', 'feature_types', 'genome', 'pattern', 'read', 'sequence'

# %% [markdown]
# ## Demultiplexing

# %% [markdown]
# - CD62 also known as L-selectin, is a resting marker, if you have it you're resting

# %%
ga = pt.pp.GuideAssignment()

# %%
mdata["cite"].X.toarray()
# Out:
# array([[3.1000e+01, 5.6000e+01, 3.0000e+01, 1.2118e+04, 3.5000e+01],
#        [2.9000e+01, 1.2531e+04, 4.5000e+01, 1.0300e+02, 1.1000e+01],
#        [2.6000e+01, 5.0790e+03, 4.5000e+01, 1.2200e+02, 9.0000e+00],
#        ...,
#        [2.4000e+01, 2.1500e+04, 4.3000e+01, 9.4000e+01, 3.2000e+01],
#        [4.3160e+03, 3.8000e+01, 2.7000e+01, 6.8000e+01, 2.7000e+01],
#        [7.5530e+03, 5.9000e+01, 7.0000e+01, 1.1900e+02, 2.1000e+01]],
#       dtype=float32)

# %%
ga.plot_heatmap(mdata["cite"], vmax = 200)

# %% [markdown]
# - while this may look like substantial contamination, this is actually normal
# - the background comes from chimeric PCR products see https://bmcgenomics.biomedcentral.com/articles/10.1186/s12864-019-5847-2
# - in order to demultiplex, i'll use hashsolo

# %%
htos = mdata["cite"].var.index.unique()

htos = [hto for hto in htos if "CD49" not in hto]

for hto in htos:
    mdata["rna"].obs[hto] = mdata["cite"].X[:, mdata["cite"].var.index == hto].toarray()

# %%
sc.external.pp.hashsolo(mdata["rna"], cell_hashing_columns=htos)
# Out:
# Please cite HashSolo paper:
# https://www.cell.com/cell-systems/fulltext/S2405-4712(20)30195-2

# %%
mask = (mdata["rna"].obs.Classification == "Doublet") | (mdata["rna"].obs.Classification == "Negative")
mu.pp.filter_obs(mdata, ~mask)

# %%
ga.plot_heatmap(mdata["cite"], vmax = 200)

# %% [markdown]
# ## Mixscape modeling

# %% [markdown]
# - first let's add in the 10x perturbation calls

# %%
pt_df = pd.read_csv("/lustre/fs4/cao_lab/scratch/plaffont/personal_datasets/CTR02/protospacer_calls_per_cell.csv")

# %%
pt_df.set_index("cell_barcode", inplace = True)

# %%
mdata["rna"].obs = mdata["rna"].obs.join(pt_df)

# %% [markdown]
# - looks like ~5000 of the barcodes are not in the 10x readout

# %%
mask = mdata["rna"].obs.feature_call.isna()

mdata["rna"].obs[mask]
# Out:
#                     spleen-CD62Lpos  spleen-CD62Lneg  mLN-CD62Lpos  \
# AAACCATTCCTCCAGC-1             27.0          15047.0          38.0
# AAACCGACAAGTCGGG-1             23.0             37.0          59.0
# AAACCGACACGGGTAG-1             12.0             23.0          14.0
# AAACCGACAGCATGGG-1           1785.0             32.0          19.0
# AAACCGACAGGCTACC-1             32.0           9041.0          50.0
# ...                             ...              ...           ...
# GTTGTGCAGCGGTTTA-1             29.0           5451.0          37.0
# GTTGTGCAGGCCATAC-1             16.0             27.0          33.0
# GTTGTGGGTAGCATCG-1             19.0             45.0          57.0
# GTTGTGGGTCTGTTAT-1           4316.0             38.0          27.0
# GTTGTGGGTGCATTGG-1           7553.0             59.0          70.0
#
#                     mLN-CD62Lneg  most_likely_hypothesis  cluster_feature  \
# AAACCATTCCTCCAGC-1         115.0                     1.0              0.0
# AAACCGACAAGTCGGG-1       16861.0                     1.0              0.0
# AAACCGACACGGGTAG-1        8447.0                     1.0              0.0
# AAACCGACAGCATGGG-1          98.0                     1.0              0.0
# AAACCGACAGGCTACC-1         107.0                     1.0              0.0
# ...                          ...                     ...              ...
# GTTGTGCAGCGGTTTA-1         125.0                     1.0              0.0
# GTTGTGCAGGCCATAC-1        1278.0                     1.0              0.0
# GTTGTGGGTAGCATCG-1        7799.0                     1.0              0.0
# GTTGTGGGTCTGTTAT-1          68.0                     1.0              0.0
# GTTGTGGGTGCATTGG-1         119.0                     1.0              0.0
#
#                     negative_hypothesis_probability  \
# AAACCATTCCTCCAGC-1                     4.144196e-15
# AAACCGACAAGTCGGG-1                     2.976061e-17
# AAACCGACACGGGTAG-1                     2.995274e-17
# AAACCGACAGCATGGG-1                     2.082251e-05
# AAACCGACAGGCTACC-1                     1.067880e-12
# ...                                             ...
# GTTGTGCAGCGGTTTA-1                     3.282348e-10
# GTTGTGCAGGCCATAC-1                     1.386223e-06
# GTTGTGGGTAGCATCG-1                     1.399550e-15
# GTTGTGGGTCTGTTAT-1                     1.913708e-09
# GTTGTGGGTGCATTGG-1                     7.153533e-12
#
#                     singlet_hypothesis_probability  \
# AAACCATTCCTCCAGC-1                        1.000000
# AAACCGACAAGTCGGG-1                        1.000000
# AAACCGACACGGGTAG-1                        1.000000
# AAACCGACAGCATGGG-1                        0.999979
# AAACCGACAGGCTACC-1                        1.000000
# ...                                            ...
# GTTGTGCAGCGGTTTA-1                        1.000000
# GTTGTGCAGGCCATAC-1                        0.999999
# GTTGTGGGTAGCATCG-1                        1.000000
# GTTGTGGGTCTGTTAT-1                        1.000000
# GTTGTGGGTGCATTGG-1                        1.000000
#
#                     doublet_hypothesis_probability   Classification  \
# AAACCATTCCTCCAGC-1                    1.286469e-07  spleen-CD62Lneg
# AAACCGACAAGTCGGG-1                    4.244691e-16     mLN-CD62Lneg
# AAACCGACACGGGTAG-1                    8.640079e-16     mLN-CD62Lneg
# AAACCGACAGCATGGG-1                    5.041451e-08  spleen-CD62Lpos
# AAACCGACAGGCTACC-1                    8.401979e-08  spleen-CD62Lneg
# ...                                            ...              ...
# GTTGTGCAGCGGTTTA-1                    2.121801e-07  spleen-CD62Lneg
# GTTGTGCAGGCCATAC-1                    4.405244e-16     mLN-CD62Lneg
# GTTGTGGGTAGCATCG-1                    4.151928e-16     mLN-CD62Lneg
# GTTGTGGGTCTGTTAT-1                    6.651367e-09  spleen-CD62Lpos
# GTTGTGGGTGCATTGG-1                    1.577876e-07  spleen-CD62Lpos
#
#                     num_features feature_call num_umis
# AAACCATTCCTCCAGC-1           NaN          NaN      NaN
# AAACCGACAAGTCGGG-1           NaN          NaN      NaN
# AAACCGACACGGGTAG-1           NaN          NaN      NaN
# AAACCGACAGCATGGG-1           NaN          NaN      NaN
# AAACCGACAGGCTACC-1           NaN          NaN      NaN
# ...                          ...          ...      ...
# GTTGTGCAGCGGTTTA-1           NaN          NaN      NaN
# GTTGTGCAGGCCATAC-1           NaN          NaN      NaN
# GTTGTGGGTAGCATCG-1           NaN          NaN      NaN
# GTTGTGGGTCTGTTAT-1           NaN          NaN      NaN
# GTTGTGGGTGCATTGG-1           NaN          NaN      NaN
#
# [5386 rows x 13 columns]

# %% [markdown]
# - now let's drop the doubles

# %% [markdown]
# ## drop cells with multiple guides

# %%
mask = ~mdata["rna"].obs.num_umis.str.contains("\|").fillna(True)

mu.pp.filter_obs(mdata, mask)
# Out:
# /tmp/ipykernel_25245/3268611832.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
# replace . with g for compatability with pertpy plotting functions
mdata["rna"].obs["feature_call"] = mdata["rna"].obs.feature_call.str.replace(".","g")

# %% [markdown]
# ## Mixscape Modeling

# %% [markdown]
# - let's add in a column for the gene target

# %%
mdata["rna"].obs["target"] = (
    mdata["rna"].obs
    .feature_call.str[:-2]
    .replace("NCC","NT")
    .replace("NTC","NT")
)

# %% [markdown]
# ### Preclustering

# %% [markdown]
# - mixscape requires dimensional reduction, so I'm going to do that here

# %%
rna = mdata["rna"]
rna
# Out:
# AnnData object with n_obs × n_vars = 17049 × 32286
#     obs: 'spleen-CD62Lpos', 'spleen-CD62Lneg', 'mLN-CD62Lpos', 'mLN-CD62Lneg', 'most_likely_hypothesis', 'cluster_feature', 'negative_hypothesis_probability', 'singlet_hypothesis_probability', 'doublet_hypothesis_probability', 'Classification', 'num_features', 'feature_call', 'num_umis', 'target'
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
rna.var["mt"] = rna.var_names.str.startswith("mt-")

sc.pp.calculate_qc_metrics(rna, inplace=True, log1p=False, percent_top=False, qc_vars="mt")

# %%
sc.pl.violin(rna, ["total_counts", "n_genes_by_counts", "pct_counts_mt"], multi_panel=True)

# %%
mu.pp.filter_obs(rna, "pct_counts_mt", lambda x: x < 20)

# %%
rna.layers["counts"] = rna.X.copy()

# %%
sc.pp.normalize_total(rna, target_sum=1e4)
sc.pp.log1p(rna)

# %%
sc.pp.highly_variable_genes(rna)

# %%
sc.pl.highly_variable_genes(rna)

# %%
sc.pp.scale(rna, max_value=10)

# %%
sc.pp.pca(rna)

# %%
sc.pl.pca_variance_ratio(rna, log=True)

# %% [markdown]
# ### Mixscape Call

# %%
ms = pt.tl.Mixscape()

# %%
mdata["rna"].obs.head()
# Out:
#                     spleen-CD62Lpos  spleen-CD62Lneg  mLN-CD62Lpos  \
# AAACCAAAGACGTTAT-1             27.0             31.0        7020.0
# AAACCAAAGATGAAGC-1             21.0             37.0        6011.0
# AAACCAAAGGTAGCTC-1             35.0            101.0        4388.0
# AAACCAGCAAAATCCC-1             37.0           7374.0          39.0
# AAACCAGCAAAGCTTC-1             33.0             42.0        6048.0
#
#                     mLN-CD62Lneg  most_likely_hypothesis  cluster_feature  \
# AAACCAAAGACGTTAT-1          89.0                     1.0              0.0
# AAACCAAAGATGAAGC-1          68.0                     1.0              0.0
# AAACCAAAGGTAGCTC-1         179.0                     1.0              0.0
# AAACCAGCAAAATCCC-1         107.0                     1.0              0.0
# AAACCAGCAAAGCTTC-1          93.0                     1.0              0.0
#
#                     negative_hypothesis_probability  \
# AAACCAAAGACGTTAT-1                     1.862517e-11
# AAACCAAAGATGAAGC-1                     6.900368e-11
# AAACCAAAGGTAGCTC-1                     1.111879e-09
# AAACCAGCAAAATCCC-1                     1.046450e-11
# AAACCAGCAAAGCTTC-1                     6.547057e-11
#
#                     singlet_hypothesis_probability  \
# AAACCAAAGACGTTAT-1                        1.000000
# AAACCAAAGATGAAGC-1                        1.000000
# AAACCAAAGGTAGCTC-1                        0.999998
# AAACCAGCAAAATCCC-1                        1.000000
# AAACCAGCAAAGCTTC-1                        1.000000
#
#                     doublet_hypothesis_probability   Classification  \
# AAACCAAAGACGTTAT-1                    2.910459e-08     mLN-CD62Lpos
# AAACCAAAGATGAAGC-1                    6.651367e-09     mLN-CD62Lpos
# AAACCAAAGGTAGCTC-1                    2.011029e-06     mLN-CD62Lpos
# AAACCAGCAAAATCCC-1                    8.401979e-08  spleen-CD62Lneg
# AAACCAGCAAAGCTTC-1                    3.734709e-08     mLN-CD62Lpos
#
#                     num_features feature_call num_umis  target  \
# AAACCAAAGACGTTAT-1           1.0     Tgfbr2g1       64  Tgfbr2
# AAACCAAAGATGAAGC-1           1.0        NCCg1      313      NT
# AAACCAAAGGTAGCTC-1           1.0     Ifngr1g4       44  Ifngr1
# AAACCAGCAAAATCCC-1           1.0     Tgfbr2g1       58  Tgfbr2
# AAACCAGCAAAGCTTC-1           1.0     Tgfbr2g1       43  Tgfbr2
#
#                     n_genes_by_counts  total_counts  total_counts_mt  \
# AAACCAAAGACGTTAT-1               6195       45470.0            786.0
# AAACCAAAGATGAAGC-1               4218       19019.0            306.0
# AAACCAAAGGTAGCTC-1               3007       12440.0            258.0
# AAACCAGCAAAATCCC-1               4505       25348.0            408.0
# AAACCAGCAAAGCTTC-1               3482       13359.0            285.0
#
#                     pct_counts_mt
# AAACCAAAGACGTTAT-1       1.728612
# AAACCAAAGATGAAGC-1       1.608917
# AAACCAAAGGTAGCTC-1       2.073955
# AAACCAGCAAAATCCC-1       1.609594
# AAACCAGCAAAGCTTC-1       2.133393

# %%
ms.perturbation_signature(mdata["rna"], pert_key = "target", control="NT")

# %%
mdata["rna"]
# Out:
# AnnData object with n_obs × n_vars = 17029 × 32286
#     obs: 'spleen-CD62Lpos', 'spleen-CD62Lneg', 'mLN-CD62Lpos', 'mLN-CD62Lneg', 'most_likely_hypothesis', 'cluster_feature', 'negative_hypothesis_probability', 'singlet_hypothesis_probability', 'doublet_hypothesis_probability', 'Classification', 'num_features', 'feature_call', 'num_umis', 'target', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'hvg', 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     layers: 'counts', 'X_pert'

# %%
ms.mixscape(adata=mdata["rna"], control="NT", labels="target", layer="X_pert")
# Out:
# /lustre/fs4/cao_lab/store/plaffont/miniforge3/envs/rapids_singlecell/lib/python3.11/site-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
# /lustre/fs4/cao_lab/store/plaffont/miniforge3/envs/rapids_singlecell/lib/python3.11/site-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2

# %%
# ms.mixscape(adata=mdata["rna"], control="target", labels="gene_target", layer="X_pert")

# this function seems to be broken. I left a comment on pertpy github issues. let's see if they fix it

# %%
mdata["rna"].obs.mixscape_class.value_counts().plot.bar()
# Out:
# <Axes: xlabel='mixscape_class'>

# %% [markdown]
# ## Subset on KO

# %%
ko_rna = rna[rna.obs.mixscape_class_global == "KO", :]

# %%
ko_rna.var_names
# Out:
# Index(['Xkr4', 'Gm1992', 'Gm19938', 'Gm37381', 'Rp1', 'Sox17', 'Gm37587',
#        'Gm37323', 'Mrpl15', 'Lypla1',
#        ...
#        'AC163611.1', 'AC163611.2', 'AC140365.1', 'AC124606.2', 'AC124606.1',
#        'AC133095.2', 'AC133095.1', 'AC234645.1', 'AC149090.1', 'pSL21-VEX'],
#       dtype='object', length=32286)

# %%
sc.pp.highly_variable_genes(ko_rna, min_mean=0.02, max_mean=4, min_disp=0.5)
sc.pp.scale(ko_rna, max_value=10)
sc.tl.pca(ko_rna, svd_solver='arpack')
sc.pp.neighbors(ko_rna, n_neighbors=10, n_pcs=25)
sc.tl.leiden(ko_rna, resolution=.7)
sc.tl.umap(ko_rna, spread=1., min_dist=.5, random_state=11)
# Out:
# /lustre/fs4/cao_lab/store/plaffont/miniforge3/envs/rapids_singlecell/lib/python3.11/site-packages/scanpy/preprocessing/_highly_variable_genes.py:305: RuntimeWarning: invalid value encountered in log
# /lustre/fs4/cao_lab/store/plaffont/miniforge3/envs/rapids_singlecell/lib/python3.11/site-packages/scanpy/preprocessing/_highly_variable_genes.py:696: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
# /lustre/fs4/cao_lab/store/plaffont/miniforge3/envs/rapids_singlecell/lib/python3.11/site-packages/scanpy/preprocessing/_scale.py:186: RuntimeWarning: invalid value encountered in sqrt

# %%
sc.tl.umap(ko_rna, spread=1., min_dist=.1, random_state=11)

# %%
sc.pl.umap(ko_rna, color = "mixscape_class")

# %%
sc.pl.umap(ko_rna, color = "leiden")

# %%
sc.pl.umap(ko_rna, color = "Classification")

# %%
ko_rna.obs.head()
# Out:
#                     spleen-CD62Lpos  spleen-CD62Lneg  mLN-CD62Lpos  \
# AAACCAAAGACGTTAT-1             27.0             31.0        7020.0
# AAACCAAAGGTAGCTC-1             35.0            101.0        4388.0
# AAACCAGCAAAATCCC-1             37.0           7374.0          39.0
# AAACCAGCAACAGAAT-1             24.0             36.0          32.0
# AAACCAGCAACCTTAA-1             22.0           9521.0          35.0
#
#                     mLN-CD62Lneg  most_likely_hypothesis  cluster_feature  \
# AAACCAAAGACGTTAT-1          89.0                     1.0              0.0
# AAACCAAAGGTAGCTC-1         179.0                     1.0              0.0
# AAACCAGCAAAATCCC-1         107.0                     1.0              0.0
# AAACCAGCAACAGAAT-1       13858.0                     1.0              0.0
# AAACCAGCAACCTTAA-1          90.0                     1.0              0.0
#
#                     negative_hypothesis_probability  \
# AAACCAAAGACGTTAT-1                     1.862517e-11
# AAACCAAAGGTAGCTC-1                     1.111879e-09
# AAACCAGCAAAATCCC-1                     1.046450e-11
# AAACCAGCAACAGAAT-1                     2.772747e-17
# AAACCAGCAACCTTAA-1                     6.015559e-13
#
#                     singlet_hypothesis_probability  \
# AAACCAAAGACGTTAT-1                        1.000000
# AAACCAAAGGTAGCTC-1                        0.999998
# AAACCAGCAAAATCCC-1                        1.000000
# AAACCAGCAACAGAAT-1                        1.000000
# AAACCAGCAACCTTAA-1                        1.000000
#
#                     doublet_hypothesis_probability   Classification  ...  \
# AAACCAAAGACGTTAT-1                    2.910459e-08     mLN-CD62Lpos  ...
# AAACCAAAGGTAGCTC-1                    2.011029e-06     mLN-CD62Lpos  ...
# AAACCAGCAAAATCCC-1                    8.401979e-08  spleen-CD62Lneg  ...
# AAACCAGCAACAGAAT-1                    4.175113e-16     mLN-CD62Lneg  ...
# AAACCAGCAACCTTAA-1                    3.100201e-08  spleen-CD62Lneg  ...
#
#                     num_umis  target n_genes_by_counts total_counts  \
# AAACCAAAGACGTTAT-1        64  Tgfbr2              6195      45470.0
# AAACCAAAGGTAGCTC-1        44  Ifngr1              3007      12440.0
# AAACCAGCAAAATCCC-1        58  Tgfbr2              4505      25348.0
# AAACCAGCAACAGAAT-1       405  Tgfbr2              4101      16909.0
# AAACCAGCAACCTTAA-1       120  Tgfbr2              4166      16785.0
#
#                     total_counts_mt  pct_counts_mt  mixscape_class_p_ko  \
# AAACCAAAGACGTTAT-1            786.0       1.728612                    1
# AAACCAAAGGTAGCTC-1            258.0       2.073955                    1
# AAACCAGCAAAATCCC-1            408.0       1.609594                    1
# AAACCAGCAACAGAAT-1            241.0       1.425277                    1
# AAACCAGCAACCTTAA-1            381.0       2.269884                    1
#
#                     mixscape_class  mixscape_class_global leiden
# AAACCAAAGACGTTAT-1       Tgfbr2 KO                     KO      5
# AAACCAAAGGTAGCTC-1       Ifngr1 KO                     KO      1
# AAACCAGCAAAATCCC-1       Tgfbr2 KO                     KO      5
# AAACCAGCAACAGAAT-1       Tgfbr2 KO                     KO      4
# AAACCAGCAACCTTAA-1       Tgfbr2 KO                     KO      3
#
# [5 rows x 22 columns]

# %%
(
    ko_rna
    .obs
    .query("mixscape_class == 'Ifngr1 KO'")
    .Classification
    .value_counts()
    .plot
    .bar(title = "CD62 composition of Ifgnr1 KO")
)
# Out:
# <Axes: title={'center': 'CD62 composition of Ifgnr1 KO'}, xlabel='Classification'>

# %%
ko_df = ko_rna.obs

# %%
ko_df.head()
# Out:
#                     spleen-CD62Lpos  spleen-CD62Lneg  mLN-CD62Lpos  \
# AAACCAAAGACGTTAT-1             27.0             31.0        7020.0
# AAACCAAAGGTAGCTC-1             35.0            101.0        4388.0
# AAACCAGCAAAATCCC-1             37.0           7374.0          39.0
# AAACCAGCAACAGAAT-1             24.0             36.0          32.0
# AAACCAGCAACCTTAA-1             22.0           9521.0          35.0
#
#                     mLN-CD62Lneg  most_likely_hypothesis  cluster_feature  \
# AAACCAAAGACGTTAT-1          89.0                     1.0              0.0
# AAACCAAAGGTAGCTC-1         179.0                     1.0              0.0
# AAACCAGCAAAATCCC-1         107.0                     1.0              0.0
# AAACCAGCAACAGAAT-1       13858.0                     1.0              0.0
# AAACCAGCAACCTTAA-1          90.0                     1.0              0.0
#
#                     negative_hypothesis_probability  \
# AAACCAAAGACGTTAT-1                     1.862517e-11
# AAACCAAAGGTAGCTC-1                     1.111879e-09
# AAACCAGCAAAATCCC-1                     1.046450e-11
# AAACCAGCAACAGAAT-1                     2.772747e-17
# AAACCAGCAACCTTAA-1                     6.015559e-13
#
#                     singlet_hypothesis_probability  \
# AAACCAAAGACGTTAT-1                        1.000000
# AAACCAAAGGTAGCTC-1                        0.999998
# AAACCAGCAAAATCCC-1                        1.000000
# AAACCAGCAACAGAAT-1                        1.000000
# AAACCAGCAACCTTAA-1                        1.000000
#
#                     doublet_hypothesis_probability   Classification  ...  \
# AAACCAAAGACGTTAT-1                    2.910459e-08     mLN-CD62Lpos  ...
# AAACCAAAGGTAGCTC-1                    2.011029e-06     mLN-CD62Lpos  ...
# AAACCAGCAAAATCCC-1                    8.401979e-08  spleen-CD62Lneg  ...
# AAACCAGCAACAGAAT-1                    4.175113e-16     mLN-CD62Lneg  ...
# AAACCAGCAACCTTAA-1                    3.100201e-08  spleen-CD62Lneg  ...
#
#                     num_umis  target n_genes_by_counts total_counts  \
# AAACCAAAGACGTTAT-1        64  Tgfbr2              6195      45470.0
# AAACCAAAGGTAGCTC-1        44  Ifngr1              3007      12440.0
# AAACCAGCAAAATCCC-1        58  Tgfbr2              4505      25348.0
# AAACCAGCAACAGAAT-1       405  Tgfbr2              4101      16909.0
# AAACCAGCAACCTTAA-1       120  Tgfbr2              4166      16785.0
#
#                     total_counts_mt  pct_counts_mt  mixscape_class_p_ko  \
# AAACCAAAGACGTTAT-1            786.0       1.728612                    1
# AAACCAAAGGTAGCTC-1            258.0       2.073955                    1
# AAACCAGCAAAATCCC-1            408.0       1.609594                    1
# AAACCAGCAACAGAAT-1            241.0       1.425277                    1
# AAACCAGCAACCTTAA-1            381.0       2.269884                    1
#
#                     mixscape_class  mixscape_class_global leiden
# AAACCAAAGACGTTAT-1       Tgfbr2 KO                     KO      5
# AAACCAAAGGTAGCTC-1       Ifngr1 KO                     KO      1
# AAACCAGCAAAATCCC-1       Tgfbr2 KO                     KO      5
# AAACCAGCAACAGAAT-1       Tgfbr2 KO                     KO      4
# AAACCAGCAACCTTAA-1       Tgfbr2 KO                     KO      3
#
# [5 rows x 22 columns]

# %% [markdown]
# - this looks really good
# - looks like the IFNg knockouts tend to be enriched for CD26 which is good because we would expect them to be resting

# %% [markdown]
# ## Gene enrichment

# %%
sc.tl.rank_genes_groups(ko_rna, groupby="mixscape_class")
# Out:
# /lustre/fs4/cao_lab/store/plaffont/miniforge3/envs/rapids_singlecell/lib/python3.11/site-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
# /lustre/fs4/cao_lab/store/plaffont/miniforge3/envs/rapids_singlecell/lib/python3.11/site-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2

# %%
sc.pl.rank_genes_groups_matrixplot(ko_rna, groupby="mixscape_class", swap_axes = True)
# Out:
# WARNING: Dendrogram not added. Dendrogram is added only when the number of categories to plot > 2

# %%
sc.pl.umap(ko_rna, color="Sell")

# %% [markdown]
# ### Check Cluster DE genes

# %%
sc.tl.leiden(ko_rna, resolution = 0.3)

# %%
sc.tl.rank_genes_groups(ko_rna, groupby="leiden")
# Out:
# /lustre/fs4/cao_lab/store/plaffont/miniforge3/envs/rapids_singlecell/lib/python3.11/site-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
# /lustre/fs4/cao_lab/store/plaffont/miniforge3/envs/rapids_singlecell/lib/python3.11/site-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
# /lustre/fs4/cao_lab/store/plaffont/miniforge3/envs/rapids_singlecell/lib/python3.11/site-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
# /lustre/fs4/cao_lab/store/plaffont/miniforge3/envs/rapids_singlecell/lib/python3.11/site-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2

# %%
sc.pl.umap(ko_rna, color=["leiden", "mixscape_class"])

# %%
sc.tl.dendrogram(ko_rna, groupby="leiden")
sc.pl.rank_genes_groups_matrixplot(ko_rna, vmax = 2)

# %% [markdown]
# ## Check the bias

# %%
(
    p9.ggplot(rna.obs, p9.aes(x = "target", fill = "target")) +
    p9.geom_bar() +
    p9.facet_wrap("~Classification") +
    p9.theme_minimal()
)
